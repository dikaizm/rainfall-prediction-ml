# %%
import pickle

with open('../data/processed/weatherAU-processed.pkl', 'rb') as f:
    df = pickle.load(f)
    
df.head()
# Out:
#    Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation   Sunshine  \
# 0   395         2     13.4     22.9       0.6     5.744037   7.314530
# 1   396         2      7.4     25.1       0.0     5.657635  11.464943
# 2   397         2     12.9     25.7       0.0     7.779909  12.236955
# 3   398         2      9.2     28.0       0.0     5.955201  11.765782
# 4   399         2     17.5     32.3       1.0     6.825401   5.769752
#
#    WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity3pm  Pressure9am  \
# 0           13           44.0          13  ...         22.0       1007.7
# 1           14           44.0           6  ...         25.0       1010.6
# 2           15           46.0          13  ...         30.0       1007.6
# 3            4           24.0           9  ...         16.0       1017.6
# 4           13           41.0           1  ...         33.0       1010.8
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# ...
